# %%
#Install libraries

# !pip install -q bitsandbytes accelerate transformers diffusers datasets safetensors
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 12.7 MB/s eta 0:00:00

# %%
#Clone the diffusers repo and go to the SDXL example folder

# %cd /content
# !git clone https://github.com/huggingface/diffusers.git
# %cd diffusers
# !pip install -e .
# %cd examples/text_to_image
# Out:
# /content
# Cloning into 'diffusers'...
# remote: Enumerating objects: 111442, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 111442 (delta 34), reused 11 (delta 8), pack-reused 111365 (from 2)
# Receiving objects: 100% (111442/111442), 83.99 MiB | 22.29 MiB/s, done.
# Resolving deltas: 100% (83108/83108), done.
# /content/diffusers
# Obtaining file:///content/diffusers
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.36.0.dev0-0.editable-py3-none-any.whl size=11374 sha256=5e1ec634269854378e3433534b26539e980399c4fd11d632a9d00d9fc33e3990
# ...

# %%
# !pip install -r requirements_sdxl.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.9 MB/s eta 0:00:00
# ...

# %%
# !pip install wandb

# %%
from huggingface_hub import login
from google.colab import userdata


hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: gunawatshubham (gunawatshubham-hoongke-tech) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
import os

os.environ["MODEL_NAME"] = "stabilityai/stable-diffusion-xl-base-1.0"

os.environ["VAE_NAME"] = "madebyollin/sdxl-vae-fp16-fix"
os.environ["DATASET_NAME"] = "lambdalabs/naruto-blip-captions"


os.environ["OUTPUT_DIR"] = "/content/sdxl-naruto-lora"

# %%
from google.colab import drive
drive.mount('/content/drive')
os.environ["OUTPUT_DIR"] = "/content/drive/MyDrive/sdxl-naruto-lora"
# Out:
# Mounted at /content/drive

# %%
# !accelerate launch train_text_to_image_lora_sdxl.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --pretrained_vae_model_name_or_path=$VAE_NAME \
  --dataset_name=$DATASET_NAME \
  --validation_prompt="An old man with blue eyes and white hair, holding a sword" \
  --num_validation_images=4 \
  --validation_epochs=5 \
  --caption_column="text" \
  --output_dir="$OUTPUT_DIR" \
  --resolution=512 \
  --random_flip \
  --train_batch_size=1 \
  --gradient_accumulation_steps=8 \
  --num_train_epochs=3 \
  --checkpointing_steps=100 \
  --learning_rate=0.0005 \
  --lr_warmup_steps=0 \
  --dataloader_num_workers=1 \
  --mixed_precision="fp16" \
  --gradient_checkpointing \
  --allow_tf32 \
  --report_to="wandb" \
  --max_train_steps=500 \
  --seed=42
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2025-11-20 04:59:04.488750: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763614744.508448    1676 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
